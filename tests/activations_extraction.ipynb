# %%
import pickle
import tensorflow as tf

dnn = pickle.load(open('cnn.model','rb'))
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data(path='mnist.npz')

predictions = dnn.predict(x_train[:10],output=['conv1','conv2','conv3'])

# %%
import matplotlib.pyplot as plt

fig,ax = plt.subplots(nrows=10,ncols=8,figsize=(6,6))
for i,pred in enumerate(predictions['conv1']):
    for j in range(8):
        ax[i,j].imshow(pred[:,:,j])
        ax[i,j].axis('off')
plt.subplots_adjust(wspace=0.001,hspace=0.001)

# %%
fig,ax = plt.subplots(nrows=10,ncols=8,figsize=(6,6))
for i,pred in enumerate(predictions['conv2']):
    for j in range(8):
        ax[i,j].imshow(pred[:,:,j])
        ax[i,j].axis('off')
plt.subplots_adjust(wspace=0.001,hspace=0.001)

# %%
fig,ax = plt.subplots(nrows=10,ncols=32,figsize=(16,5))
for i,pred in enumerate(predictions['conv3']):
    for j in range(32):
        ax[i,j].imshow(pred[:,:,j])
        ax[i,j].axis('off')
plt.subplots_adjust(wspace=0.04,hspace=0.04)
